# %% [markdown]
# # Recommendation System

# %%
from collections import Counter

import pandas as pd
import numpy as np

import pickle as pk

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

from jupyterthemes import jtplot
jtplot.style(figsize=(15, 9))

# %% [markdown]
# ## Data

# %% [markdown]
# ### Movies

# %%
movies = pd.read_csv('../data/popular_10000_movies/movies_dataset_CLEAN.csv', index_col='id')
movies.head()
# Out:
#                       genre_ids  \
# id
# 385687             [28, 80, 53]
# 697843                 [28, 53]
# 603692             [28, 53, 80]
# 569094        [28, 12, 16, 878]
# 502356  [16, 10751, 12, 14, 35]
#
#                                                  overview  popularity  \
# id
# 385687  Over many missions and against impossible odds...    4654.279
# 697843  Tasked with extracting a family who is at the ...    2494.010
# 603692  With the price on his head ever increasing, Jo...    1920.127
# 569094  After reuniting with Gwen Stacy, Brooklyn’s fu...    2013.795
# 502356  While working underground to fix a water main,...    1539.037
#
#        release_date                                title  vote_average  \
# id
# 385687   2023-05-17                               Fast X           7.3
# 697843   2023-06-09                         Extraction 2           7.7
# 603692   2023-03-22                 John Wick: Chapter 4           7.9
# 569094   2023-05-31  Spider-Man: Across the Spider-Verse           8.6
# 502356   2023-04-05          The Super Mario Bros. Movie           7.8
#
#         vote_count                                         genres  \
# id
# 385687        2093                        Action, Crime, Thriller
# 697843         910                               Action, Thriller
# 603692        3344                        Action, Thriller, Crime
# 569094        1796  Action, Adventure, Animation, Science Fiction
# 502356        5165  Animation, Family, Adventure, Fantasy, Comedy
#
#                                                      cast  \
# id
# 385687  [{'cast_id': 12835, 'name': 'Vin Diesel', 'cha...
# 697843  [{'cast_id': 74568, 'name': 'Chris Hemsworth',...
# 603692  [{'cast_id': 6384, 'name': 'Keanu Reeves', 'ch...
# 569094  [{'cast_id': 587506, 'name': 'Shameik Moore', ...
# 502356  [{'cast_id': 73457, 'name': 'Chris Pratt', 'ch...
#
#                                                      crew  \
# id
# 385687  [{'crew_id': 1302, 'name': 'Susie Figgis', 'de...
# 697843  [{'crew_id': 950, 'name': 'Pietro Scalia', 'de...
# 603692  [{'crew_id': 3615, 'name': 'Manfred Banach', '...
# 569094  [{'crew_id': 7624, 'name': 'Stan Lee', 'depart...
# 502356  [{'crew_id': 70851, 'name': 'Jack Black', 'dep...
#
#                                                  keywords
# id
# 385687  [{'id': 9663, 'name': 'sequel'}, {'id': 9748, ...
# 697843  [{'id': 3070, 'name': 'mercenary'}, {'id': 966...
# 603692  [{'id': 242, 'name': 'new york city'}, {'id': ...
# 569094  [{'id': 2858, 'name': 'sacrifice'}, {'id': 328...
# 502356  [{'id': 282, 'name': 'video game'}, {'id': 690...

# %%
movies = movies[['popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
movies.head()
# Out:
#         popularity release_date                                title  \
# id
# 385687    4654.279   2023-05-17                               Fast X
# 697843    2494.010   2023-06-09                         Extraction 2
# 603692    1920.127   2023-03-22                 John Wick: Chapter 4
# 569094    2013.795   2023-05-31  Spider-Man: Across the Spider-Verse
# 502356    1539.037   2023-04-05          The Super Mario Bros. Movie
#
#         vote_average  vote_count
# id
# 385687           7.3        2093
# 697843           7.7         910
# 603692           7.9        3344
# 569094           8.6        1796
# 502356           7.8        5165

# %%
movies.dtypes
# Out:
# popularity      float64
# release_date     object
# title            object
# vote_average    float64
# vote_count        int64
# dtype: object

# %% [markdown]
# ### Genres: cosine similarity and one-hot labeling

# %%
genres_cs = pd.read_csv('data/genres_cosine_similarity.csv', index_col=0)
genres_cs
# Out:
#                  TV Movie  Thriller    Action   Mystery     Crime  \
# TV Movie         1.000000  0.394733  0.513236  0.396730  0.364897
# Thriller         0.394733  1.000000  0.717784  0.803086  0.803562
# Action           0.513236  0.717784  1.000000  0.554684  0.650536
# Mystery          0.396730  0.803086  0.554684  1.000000  0.702164
# Crime            0.364897  0.803562  0.650536  0.702164  1.000000
# Documentary      0.273702  0.252943  0.291962  0.263122  0.289151
# Adventure        0.592527  0.478655  0.797106  0.456686  0.422055
# Science Fiction  0.535230  0.632004  0.781199  0.554591  0.450467
# Drama            0.511371  0.747659  0.623967  0.662259  0.701130
# Animation        0.599006  0.276127  0.589238  0.365163  0.281047
# Music            0.580721  0.261950  0.364484  0.314863  0.310511
# Fantasy          0.615960  0.419476  0.625936  0.449878  0.349360
# Family           0.676505  0.280956  0.571553  0.368790  0.297321
# Romance          0.495483  0.495854  0.473524  0.471931  0.481107
# Western          0.354297  0.468874  0.555539  0.387748  0.460968
# War              0.326719  0.527351  0.573059  0.379926  0.420063
# History          0.332524  0.504018  0.479258  0.384377  0.462907
# Horror           0.410583  0.717057  0.612385  0.646352  0.507797
# Comedy           0.677208  0.440748  0.641312  0.491783  0.503363
#
#                  Documentary  Adventure  Science Fiction     Drama  Animation  \
# TV Movie            0.273702   0.592527         0.535230  0.511371   0.599006
# Thriller            0.252943   0.478655         0.632004  0.747659   0.276127
# Action              0.291962   0.797106         0.781199  0.623967   0.589238
# Mystery             0.263122   0.456686         0.554591  0.662259   0.365163
# Crime               0.289151   0.422055         0.450467  0.701130   0.281047
# Documentary         1.000000   0.247916         0.216827  0.337446   0.169529
# Adventure           0.247916   1.000000         0.719617  0.537524   0.801408
# Science Fiction     0.216827   0.719617         1.000000  0.512783   0.598825
# Drama               0.337446   0.537524         0.512783  1.000000   0.351065
# Animation           0.169529   0.801408         0.598825  0.351065   1.000000
# Music               0.257017   0.530574         0.354121  0.497333   0.590689
# Fantasy             0.192158   0.794288         0.613756  0.496137   0.775147
# Family              0.198267   0.831916         0.575048  0.432878   0.926371
# Romance             0.221919   0.530338         0.428716  0.725442   0.421453
# Western             0.214639   0.534050         0.385528  0.603654   0.339857
# War                 0.240606   0.451217         0.382743  0.706889   0.239284
# History             0.312933   0.386237         0.295121  0.748685   0.198830
# Horror              0.220365   0.464983         0.641385  0.516213   0.339585
# Comedy              0.274301   0.784823         0.601664  0.542533   0.789651
#
#                     Music   Fantasy    Family   Romance   Western       War  \
# TV Movie         0.580721  0.615960  0.676505  0.495483  0.354297  0.326719
# Thriller         0.261950  0.419476  0.280956  0.495854  0.468874  0.527351
# Action           0.364484  0.625936  0.571553  0.473524  0.555539  0.573059
# Mystery          0.314863  0.449878  0.368790  0.471931  0.387748  0.379926
# Crime            0.310511  0.349360  0.297321  0.481107  0.460968  0.420063
# Documentary      0.257017  0.192158  0.198267  0.221919  0.214639  0.240606
# Adventure        0.530574  0.794288  0.831916  0.530338  0.534050  0.451217
# Science Fiction  0.354121  0.613756  0.575048  0.428716  0.385528  0.382743
# Drama            0.497333  0.496137  0.432878  0.725442  0.603654  0.706889
# Animation        0.590689  0.775147  0.926371  0.421453  0.339857  0.239284
# Music            1.000000  0.609684  0.677975  0.597030  0.319886  0.277159
# Fantasy          0.609684  1.000000  0.827836  0.550375  0.382767  0.303073
# Family           0.677975  0.827836  1.000000  0.521147  0.373618  0.264771
# Romance          0.597030  0.550375  0.521147  1.000000  0.498564  0.486483
# Western          0.319886  0.382767  0.373618  0.498564  1.000000  0.429411
# War              0.277159  0.303073  0.264771  0.486483  0.429411  1.000000
# History          0.303492  0.259801  0.244276  0.473519  0.433182  0.799357
# Horror           0.281107  0.545390  0.334294  0.373366  0.347704  0.335557
# Comedy           0.711368  0.781311  0.857971  0.641448  0.455509  0.334201
#
#                   History    Horror    Comedy
# TV Movie         0.332524  0.410583  0.677208
# Thriller         0.504018  0.717057  0.440748
# Action           0.479258  0.612385  0.641312
# Mystery          0.384377  0.646352  0.491783
# Crime            0.462907  0.507797  0.503363
# Documentary      0.312933  0.220365  0.274301
# Adventure        0.386237  0.464983  0.784823
# Science Fiction  0.295121  0.641385  0.601664
# Drama            0.748685  0.516213  0.542533
# Animation        0.198830  0.339585  0.789651
# Music            0.303492  0.281107  0.711368
# Fantasy          0.259801  0.545390  0.781311
# Family           0.244276  0.334294  0.857971
# Romance          0.473519  0.373366  0.641448
# Western          0.433182  0.347704  0.455509
# War              0.799357  0.335557  0.334201
# History          1.000000  0.285758  0.298909
# Horror           0.285758  1.000000  0.466110
# Comedy           0.298909  0.466110  1.000000

# %%
genres_oh = pd.read_csv('data/one-hot_genres.csv', index_col='id')
genres_oh.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687       1          0          0       0      1            0      0
# 697843       1          0          0       0      0            0      0
# 603692       1          0          0       0      1            0      0
# 569094       1          1          1       0      0            0      0
# 502356       0          1          1       1      0            0      0
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687       0        0        0       0      0        0        0
# 697843       0        0        0       0      0        0        0
# 603692       0        0        0       0      0        0        0
# 569094       0        0        0       0      0        0        0
# 502356       1        1        0       0      0        0        0
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687                0         0         1    0        0
# 697843                0         0         1    0        0
# 603692                0         0         1    0        0
# 569094                1         0         0    0        0
# 502356                0         0         0    0        0

# %%
genres_oh.loc[movies.index]
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687       1          0          0       0      1            0      0
# 697843       1          0          0       0      0            0      0
# 603692       1          0          0       0      1            0      0
# 569094       1          1          1       0      0            0      0
# 502356       0          1          1       1      0            0      0
# ...        ...        ...        ...     ...    ...          ...    ...
# 15017        0          0          0       1      0            0      0
# 79509        1          0          0       1      0            0      0
# 13370        0          0          0       1      0            0      0
# 480623       0          0          0       0      0            0      0
# 465109       0          0          0       1      0            0      0
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687       0        0        0       0      0        0        0
# 697843       0        0        0       0      0        0        0
# 603692       0        0        0       0      0        0        0
# 569094       0        0        0       0      0        0        0
# 502356       1        1        0       0      0        0        0
# ...        ...      ...      ...     ...    ...      ...      ...
# 15017        0        0        0       0      0        0        1
# 79509        0        0        0       0      0        0        0
# 13370        0        0        0       0      1        0        0
# 480623       0        0        0       0      0        0        1
# 465109       0        0        0       0      0        0        0
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687                0         0         1    0        0
# 697843                0         0         1    0        0
# 603692                0         0         1    0        0
# 569094                1         0         0    0        0
# 502356                0         0         0    0        0
# ...                 ...       ...       ...  ...      ...
# 15017                 0         0         0    0        0
# 79509                 0         0         1    0        0
# 13370                 0         0         0    0        0
# 480623                0         1         0    0        0
# 465109                0         0         0    0        0
#
# [9182 rows x 19 columns]

# %%
genres_oh = genres_oh[~genres_oh.index.duplicated(keep='first')]

# %%
genres_oh.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687       1          0          0       0      1            0      0
# 697843       1          0          0       0      0            0      0
# 603692       1          0          0       0      1            0      0
# 569094       1          1          1       0      0            0      0
# 502356       0          1          1       1      0            0      0
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687       0        0        0       0      0        0        0
# 697843       0        0        0       0      0        0        0
# 603692       0        0        0       0      0        0        0
# 569094       0        0        0       0      0        0        0
# 502356       1        1        0       0      0        0        0
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687                0         0         1    0        0
# 697843                0         0         1    0        0
# 603692                0         0         1    0        0
# 569094                1         0         0    0        0
# 502356                0         0         0    0        0

# %%
genres_oh.shape, movies.shape
# Out:
# ((9939, 19), (9144, 5))

# %% [markdown]
# ### Keywords

# %%
keywords = pd.read_csv('data/keywords_list.csv', index_col='id')
keywords.head()
# Out:
#                                             keywords_list
# id
# 385687  ['sequel', 'revenge', 'racing', 'family', 'cars']
# 697843  ['mercenary', 'sequel', 'rescue mission', 'lon...
# 603692  ['new york city', 'martial arts', 'hitman', 's...
# 569094  ['sacrifice', 'villain', 'comic book', 'sequel...
# 502356  ['video game', 'gorilla', 'plumber', 'magic mu...

# %%
keywords.shape
# Out:
# (9144, 1)

# %%
with open('data/keywords_counter.pickle', 'rb') as f:
    keywords_counter = pk.load(f)

# %%
len(keywords_counter)
# Out:
# 14239

# %%
unique_keywords = pd.read_csv('data/unique_keywords_genres_count_with_labels_SHORTED_VERSION_label_encoder.csv', index_col=0)
unique_keywords.head()
# Out:
#                  Action  Adventure  Animation  Comedy  Crime  Documentary  \
# car crash            20         10          1      16     11            0
# liposuction           0          0          0       1      0            0
# stasis                0          1          0       0      0            0
# giant vegetable       0          1          1       1      0            0
# monster              48         43         22      41      0            0
#
#                  Drama  Family  Fantasy  History  ...  Music  Mystery  \
# car crash           15       4        5        0  ...      1        6
# liposuction          1       0        1        0  ...      0        0
# stasis               0       0        0        0  ...      0        1
# giant vegetable      0       1        0        0  ...      0        0
# monster             17      27       50        0  ...      1       12
#
#                  Romance  Science Fiction  TV Movie  Thriller  War  Western  \
# car crash              3                9         1        25    0        0
# liposuction            0                0         0         0    0        0
# stasis                 0                1         0         0    0        0
# giant vegetable        0                0         0         0    0        0
# monster                0               55         8        29    1        0
#
#                                   label label_encoder
# car crash                      Thriller           233
# liposuction      Comedy, Drama, Fantasy            82
# stasis                  Science Fiction           231
# giant vegetable               Animation            63
# monster                          Horror           204
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Cast

# %%
cast = pd.read_csv('data/cast_list.csv', index_col='id')
cast.head()
# Out:
#                                                 cast_list
# id
# 385687  ['Vin Diesel', 'Michelle Rodriguez', 'Tyrese G...
# 697843  ['Chris Hemsworth', 'Golshifteh Farahani', 'Ad...
# 603692  ['Keanu Reeves', 'Donnie Yen', 'Bill Skarsgård...
# 569094  ['Shameik Moore', 'Hailee Steinfeld', 'Brian T...
# 502356  ['Chris Pratt', 'Anya Taylor-Joy', 'Charlie Da...

# %%
cast.shape
# Out:
# (9133, 1)

# %%
unique_actors = pd.read_csv('data/unique_actors_genres_count_with_labels_SHORTED_VERSION_label_encoder.csv', index_col=0)
unique_actors.head()
# Out:
#               Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# Sheldon Jett       0          0          0       1      0            0      0
# Jocelyn Ott        0          1          0       1      0            0      1
# Mel Archer         0          0          0       0      0            0      1
# Tony Aitken        0          0          0       0      0            0      1
# J.K. Simmons      24         24         12      31      9            2     30
#
#               Family  Fantasy  History  ...  Music  Mystery  Romance  \
# Sheldon Jett       0        0        0  ...      0        0        1
# Jocelyn Ott        1        1        0  ...      0        0        1
# Mel Archer         0        0        0  ...      0        0        0
# Tony Aitken        0        0        0  ...      0        0        1
# J.K. Simmons      12        9        4  ...      3        2        9
#
#               Science Fiction  TV Movie  Thriller  War  Western  \
# Sheldon Jett                0         0         0    0        0
# Jocelyn Ott                 0         0         0    0        0
# Mel Archer                  0         0         0    0        1
# Tony Aitken                 0         0         0    0        0
# J.K. Simmons               12         1        14    0        3
#
#                                  label label_encoder
# Sheldon Jett   Comedy, Romance, Action           138
# Jocelyn Ott   Adventure, Comedy, Drama            61
# Mel Archer      Drama, Western, Action           253
# Tony Aitken     Drama, Romance, Action           234
# J.K. Simmons     Comedy, Drama, Action           117
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Hey, beauty, what do you want to watch tonight?

# %%
movies_full = pd.read_csv('../data/popular_10000_movies/movies_dataset_CLEAN.csv', index_col='id')

# %%
something_like = movies_full[movies_full['title'].isin(['Starship Troopers', 'Aliens', 'Pitch Black'])]
something_like
# Out:
#               genre_ids                                           overview  \
# id
# 679       [28, 53, 878]  When Ripley's lifepod is found by a salvage cr...
# 563   [12, 28, 53, 878]  Set in the future, the story follows a young s...
# 2787      [53, 878, 28]  When their ship crash-lands on a remote planet...
#
#       popularity release_date              title  vote_average  vote_count  \
# id
# 679       59.005   1986-07-18             Aliens           7.9        8542
# 563       28.171   1997-11-07  Starship Troopers           7.0        4268
# 2787      14.899   2000-02-18        Pitch Black           6.8        3974
#
#                                             genres  \
# id
# 679              Action, Thriller, Science Fiction
# 563   Adventure, Action, Thriller, Science Fiction
# 2787             Thriller, Science Fiction, Action
#
#                                                    cast  \
# id
# 679   [{'cast_id': 10205, 'name': 'Sigourney Weaver'...
# 563   [{'cast_id': 27763, 'name': 'Casper Van Dien',...
# 2787  [{'cast_id': 12835, 'name': 'Vin Diesel', 'cha...
#
#                                                    crew  \
# id
# 679   [{'crew_id': 8380, 'name': 'Michael Lamont', '...
# 563   [{'crew_id': 3686, 'name': 'Johanna Ray', 'dep...
# 2787  [{'crew_id': 2214, 'name': 'Paul Haslinger', '...
#
#                                                keywords
# id
# 679   [{'id': 803, 'name': 'android'}, {'id': 1603, ...
# 563   [{'id': 305, 'name': 'moon'}, {'id': 818, 'nam...
# 2787  [{'id': 3762, 'name': 'darkness'}, {'id': 4565...

# %%
print('Aliens:')
print(keywords.loc[679].to_list()[0])
# Out:
# Aliens:
# ['android', 'extraterrestrial technology', 'space marine', 'spaceman', 'cryogenics', 'vacuum', 'space colony', 'warrior woman', 'settler', 'space travel', 'colony', 'space', 'alien', 'creature', 'desolate', 'xenomorph', 'desolate planet']

# %%
print('Starship Troopers:')
print(keywords.loc[563].to_list()[0])
# Out:
# Starship Troopers:
# ['moon', 'based on novel or book', 'asteroid', 'spacecraft', 'space marine', 'intelligence', 'buenos aires, argentina', 'space battle', 'dystopia', 'army', 'giant insect', 'satire', 'creature', 'soldier', 'drill instructor', 'military', 'bugs']

# %%
print('Pitch Black:')
print(keywords.loc[2787].to_list()[0])
# Out:
# Pitch Black:
# ['darkness', 'dystopia', 'comet', 'alien life-form', 'survival', 'creature', 'eclipse', 'flask', 'spaceship crash']

# %%
max(len(keywords_counter['android'].keys()), len(keywords_counter['moon'].keys()), len(keywords_counter['darkness'].keys()))
# Out:
# 304

# %%
genres_choice = something_like['genres'].to_list()
genres_choice
# Out:
# ['Action, Thriller, Science Fiction',
#  'Adventure, Action, Thriller, Science Fiction',
#  'Thriller, Science Fiction, Action']

# %%
genres_flat_list = [g for gs in genres_choice for g in gs.split(', ')]

# %%
genres_cs.loc[list(set(genres_flat_list)), list(set(genres_flat_list))]
# Out:
#                  Adventure  Science Fiction    Action  Thriller
# Adventure         1.000000         0.719617  0.797106  0.478655
# Science Fiction   0.719617         1.000000  0.781199  0.632004
# Action            0.797106         0.781199  1.000000  0.717784
# Thriller          0.478655         0.632004  0.717784  1.000000

# %%
plt.figure()
sns.heatmap(genres_cs.loc[list(set(genres_flat_list)), list(set(genres_flat_list))], annot=True)
plt.title('Correlation of genres of chosen films')
# Out:
# Text(0.5, 1.0, 'Correlation of genres of chosen films')

# %%
unique_keywords.loc[keywords.loc[679].to_list()[0][2:-2].split("', '"), list(set(genres_flat_list))]
# Out:
#                              Adventure  Science Fiction  Action  Thriller
# android                             15               43      18        17
# extraterrestrial technology          5               15       4         6
# space marine                        18               32      18        10
# spaceman                             1                2       1         2
# cryogenics                           1                5       3         1
# vacuum                               0                2       1         2
# space colony                         5                7       6         1
# warrior woman                        4                1       6         2
# settler                              2                1       2         1
# space travel                        28               47      26        12
# colony                               2                3       3         3
# space                               33               59      30        17
# alien                               57              146      64        41
# creature                            42               71      64        41
# desolate                             1                2       2         3
# xenomorph                            1                7       5         2
# desolate planet                      0                1       1         1

# %%
x = keywords.loc[679].to_list()[0][2:-2].split("', '")
y = np.arange(19)

fig, ax = plt.subplots(figsize=(17, 9))

for keyword in x:
    ax.scatter(unique_keywords.loc[keyword, genres_cs.index.to_list()].to_list(), y, label=keyword)
    
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.yaxis.set_ticks(y)
ax.set_yticklabels(unique_keywords.columns.to_list()[:-2]);

# %%
genres_flat_list
# Out:
# ['Action',
#  'Thriller',
#  'Science Fiction',
#  'Adventure',
#  'Action',
#  'Thriller',
#  'Science Fiction',
#  'Thriller',
#  'Science Fiction',
#  'Action']

# %%
y = np.arange(0, len(list(set(genres_flat_list))))

fig, ax = plt.subplots(figsize=(17, 9))

for keyword in x:
    ax.scatter(unique_keywords.loc[keyword, list(set(genres_flat_list))].to_list(), y, label=keyword)
    
ax.legend(bbox_to_anchor=(1.0, 1.0))
ax.yaxis.set_ticks(y)
ax.set_yticklabels(list(set(genres_flat_list)));
