# %% [markdown]
# # Data Prepare

# %%
from collections import Counter
from itertools import combinations
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

import matplotlib.pyplot as plt
import seaborn as sns

import pickle as pk

from jupyterthemes import jtplot
jtplot.style(figsize=(15, 9))

# %% [markdown]
# ## Data

# %%
movies = pd.read_csv('data/movies_dataset_CLEAN_noNaN.csv', index_col='id')
movies.head()
# Out:
#                       genre_ids  \
# id
# 385687             [28, 80, 53]
# 697843                 [28, 53]
# 603692             [28, 53, 80]
# 569094        [28, 12, 16, 878]
# 502356  [16, 10751, 12, 14, 35]
#
#                                                  overview  popularity  \
# id
# 385687  Over many missions and against impossible odds...    4654.279
# 697843  Tasked with extracting a family who is at the ...    2494.010
# 603692  With the price on his head ever increasing, Jo...    1920.127
# 569094  After reuniting with Gwen Stacy, Brooklyn’s fu...    2013.795
# 502356  While working underground to fix a water main,...    1539.037
#
#        release_date                                title  vote_average  \
# id
# 385687   2023-05-17                               Fast X           7.3
# 697843   2023-06-09                         Extraction 2           7.7
# 603692   2023-03-22                 John Wick: Chapter 4           7.9
# 569094   2023-05-31  Spider-Man: Across the Spider-Verse           8.6
# 502356   2023-04-05          The Super Mario Bros. Movie           7.8
#
#         vote_count                                         genres  \
# id
# 385687        2093                        Action, Crime, Thriller
# 697843         910                               Action, Thriller
# 603692        3344                        Action, Thriller, Crime
# 569094        1796  Action, Adventure, Animation, Science Fiction
# 502356        5165  Animation, Family, Adventure, Fantasy, Comedy
#
#                                                      cast  \
# id
# 385687  [{'cast_id': 12835, 'name': 'Vin Diesel', 'cha...
# 697843  [{'cast_id': 74568, 'name': 'Chris Hemsworth',...
# 603692  [{'cast_id': 6384, 'name': 'Keanu Reeves', 'ch...
# 569094  [{'cast_id': 587506, 'name': 'Shameik Moore', ...
# 502356  [{'cast_id': 73457, 'name': 'Chris Pratt', 'ch...
#
#                                                      crew  \
# id
# 385687  [{'crew_id': 1302, 'name': 'Susie Figgis', 'de...
# 697843  [{'crew_id': 950, 'name': 'Pietro Scalia', 'de...
# 603692  [{'crew_id': 3615, 'name': 'Manfred Banach', '...
# 569094  [{'crew_id': 7624, 'name': 'Stan Lee', 'depart...
# 502356  [{'crew_id': 70851, 'name': 'Jack Black', 'dep...
#
#                                                  keywords      label  \
# id
# 385687  [{'id': 9663, 'name': 'sequel'}, {'id': 9748, ...   Thriller
# 697843  [{'id': 3070, 'name': 'mercenary'}, {'id': 966...   Thriller
# 603692  [{'id': 242, 'name': 'new york city'}, {'id': ...   Thriller
# 569094  [{'id': 2858, 'name': 'sacrifice'}, {'id': 328...  Animation
# 502356  [{'id': 282, 'name': 'video game'}, {'id': 690...  Animation
#
#         label_encoder
# id
# 385687             16
# 697843             16
# 603692             16
# 569094              2
# 502356              2

# %% [markdown]
# ### DataFrame with lists

# %%
keywords = pd.read_csv('DRAFT/data/keywords_list.csv', index_col='id')
keywords.head()
# Out:
#                                             keywords_list
# id
# 385687  ['sequel', 'revenge', 'racing', 'family', 'cars']
# 697843  ['mercenary', 'sequel', 'rescue mission', 'lon...
# 603692  ['new york city', 'martial arts', 'hitman', 's...
# 569094  ['sacrifice', 'villain', 'comic book', 'sequel...
# 502356  ['video game', 'gorilla', 'plumber', 'magic mu...

# %%
crew = pd.read_csv('DRAFT/data/crew_list.csv', index_col='id')
crew.head()
# Out:
#                                                     crew_
# id
# 385687  ['Zach Dean', 'Amanda Lewis', 'Gary Scott Thom...
# 697843  ['Mike Larocca', 'Stephen McFeely', 'Joe Russo...
# 603692  ['Michael Finch', 'Louise Rosner-Meyer', 'Henn...
# 569094  ['Griffin Johnston', 'Phil Lord', 'Robert Jonk...
# 502356  ['David D. Au', 'Michael Jelenic', 'Matt Fogel...

# %%
cast = pd.read_csv('DRAFT/data/cast_list.csv', index_col='id')
cast.head()
# Out:
#                                                 cast_list
# id
# 385687  ['Vin Diesel', 'Michelle Rodriguez', 'Tyrese G...
# 697843  ['Chris Hemsworth', 'Golshifteh Farahani', 'Ad...
# 603692  ['Keanu Reeves', 'Donnie Yen', 'Bill Skarsgård...
# 569094  ['Shameik Moore', 'Hailee Steinfeld', 'Brian T...
# 502356  ['Chris Pratt', 'Anya Taylor-Joy', 'Charlie Da...

# %% [markdown]
# ### One-Hot genres

# %%
oh_genres = pd.read_csv('data/genres_vectors.csv', index_col='id')
oh_genres.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687       1          0          0       0      1            0      0
# 697843       1          0          0       0      0            0      0
# 603692       1          0          0       0      1            0      0
# 569094       1          1          1       0      0            0      0
# 502356       0          1          1       1      0            0      0
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687       0        0        0       0      0        0        0
# 697843       0        0        0       0      0        0        0
# 603692       0        0        0       0      0        0        0
# 569094       0        0        0       0      0        0        0
# 502356       1        1        0       0      0        0        0
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687                0         0         1    0        0
# 697843                0         0         1    0        0
# 603692                0         0         1    0        0
# 569094                1         0         0    0        0
# 502356                0         0         0    0        0

# %%
keywords = keywords.loc[movies.index]
cast     = cast.loc[movies.index]
crew     = crew.loc[movies.index]

# %%
movies.shape, keywords.shape, crew.shape, cast.shape, oh_genres.shape
# Out:
# ((9130, 13), (9130, 1), (9130, 1), (9130, 1), (9130, 19))

# %% [markdown]
# ### Unique lists

# %%
with open('DRAFT/data/unique_genres_list.pickle', 'rb') as f:
    u_genres = pk.load(f)

u_genres
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western']

# %%
with open('DRAFT/data/unique_crew_list.pickle', 'rb') as f:
    u_crew = pk.load(f)

u_crew[:10]
# Out:
# ['Harmon Kaslow',
#  'Gene Patterson',
#  'Shirel Kozak',
#  'Paul Freiberger',
#  'Alex Theurer',
#  'David Fountain',
#  'Jean Skinner',
#  'Gerardo Gatica',
#  'Rich Thorne',
#  'Iddo Lampton Enochs Jr.']

# %%
with open('DRAFT/data/unique_cast_list.pickle', 'rb') as f:
    u_cast = pk.load(f)

u_cast[:10]
# Out:
# ['Pat Thomson',
#  'John Matuszak',
#  'Gustave Tassell',
#  'Nathalie Richard',
#  'Donald Petersen',
#  'George DelHoyo',
#  'Zane Cassidy',
#  'Mikey Madison',
#  'Donald MacBride',
#  'Holly Horne']

# %%
with open('DRAFT/data/unique_keywords_list.pickle', 'rb') as f:
    u_keywords = pk.load(f)

u_keywords[:10]
# Out:
# ['car crash',
#  'liposuction',
#  'stasis',
#  'giant vegetable',
#  'monster',
#  'osama bin laden',
#  'yonkers, new york',
#  'jazz singer or musician',
#  'chemical plant',
#  'honesty']

# %% [markdown]
# ## Vectors

# %% [markdown]
# ### Simple Vectors

# %%
def get_vectors(df: pd.DataFrame, unique_list: list)->pd.DataFrame:
    df_vectors = pd.DataFrame(0, index=unique_list, columns=u_genres)
    df_vectors.head()
    
    for _id in df.index:
        row = df.loc[_id].to_list()[0][2: -2].split("', '")
        genres_vector = oh_genres.loc[_id].to_list()
        for item in row:
            df_vectors.loc[item] += genres_vector
    
    return df_vectors

# %%
keywords_vectors = get_vectors(keywords, u_keywords)
keywords_vectors.head()
# Out:
#                  Action  Adventure  Animation  Comedy  Crime  Documentary  \
# car crash            20         10          1      16     11            0
# liposuction           0          0          0       1      0            0
# stasis                0          1          0       0      0            0
# giant vegetable       0          1          1       1      0            0
# monster              48         43         22      41      0            0
#
#                  Drama  Family  Fantasy  History  Horror  Music  Mystery  \
# car crash           15       4        5        0       8      1        6
# liposuction          1       0        1        0       0      0        0
# stasis               0       0        0        0       0      0        1
# giant vegetable      0       1        0        0       0      0        0
# monster             17      27       50        0      71      1       12
#
#                  Romance  Science Fiction  TV Movie  Thriller  War  Western
# car crash              3                9         1        25    0        0
# liposuction            0                0         0         0    0        0
# stasis                 0                1         0         0    0        0
# giant vegetable        0                0         0         0    0        0
# monster                0               55         8        29    1        0

# %%
keywords_vectors.to_csv('data/keywords_vectors.csv')

# %%
crew_vectors = get_vectors(crew, u_crew)
crew_vectors.head()
# Out:
#                  Action  Adventure  Animation  Comedy  Crime  Documentary  \
# Harmon Kaslow         1          0          0       0      0            0
# Gene Patterson        0          0          0       0      1            0
# Shirel Kozak          0          0          0       0      0            1
# Paul Freiberger       0          0          0       0      0            0
# Alex Theurer          0          0          0       0      0            0
#
#                  Drama  Family  Fantasy  History  Horror  Music  Mystery  \
# Harmon Kaslow        0       0        0        0       1      0        0
# Gene Patterson       0       0        0        0       0      0        1
# Shirel Kozak         0       0        0        0       0      0        0
# Paul Freiberger      1       0        0        0       0      0        0
# Alex Theurer         0       0        0        0       1      0        0
#
#                  Romance  Science Fiction  TV Movie  Thriller  War  Western
# Harmon Kaslow          0                0         0         1    0        0
# Gene Patterson         0                0         0         1    0        0
# Shirel Kozak           0                0         0         0    0        0
# Paul Freiberger        0                0         0         0    0        0
# Alex Theurer           0                0         0         1    0        0

# %%
crew_vectors.to_csv('data/crew_vectors.csv')

# %%
cast_vectors = get_vectors(cast, u_cast)
cast_vectors.head()
# Out:
#                   Action  Adventure  Animation  Comedy  Crime  Documentary  \
# Pat Thomson            0          0          0       1      0            0
# John Matuszak          0          2          0       2      0            0
# Gustave Tassell        0          0          0       1      0            0
# Nathalie Richard       0          0          0       0      0            0
# Donald Petersen        0          0          0       0      0            0
#
#                   Drama  Family  Fantasy  History  Horror  Music  Mystery  \
# Pat Thomson           2       0        0        0       0      0        0
# John Matuszak         0       1        0        0       0      0        0
# Gustave Tassell       1       0        0        0       0      0        0
# Nathalie Richard      1       0        0        0       0      0        0
# Donald Petersen       0       0        1        0       1      0        0
#
#                   Romance  Science Fiction  TV Movie  Thriller  War  Western
# Pat Thomson             1                0         0         0    0        0
# John Matuszak           0                0         0         0    0        0
# Gustave Tassell         1                0         0         0    0        0
# Nathalie Richard        1                1         0         0    0        0
# Donald Petersen         0                0         0         1    0        0

# %%
cast_vectors.to_csv('data/cast_vectors.csv')

# %%
cast
# Out:
#                                                 cast_list
# id
# 385687  ['Vin Diesel', 'Michelle Rodriguez', 'Tyrese G...
# 697843  ['Chris Hemsworth', 'Golshifteh Farahani', 'Ad...
# 603692  ['Keanu Reeves', 'Donnie Yen', 'Bill Skarsgård...
# 569094  ['Shameik Moore', 'Hailee Steinfeld', 'Brian T...
# 502356  ['Chris Pratt', 'Anya Taylor-Joy', 'Charlie Da...
# ...                                                   ...
# 15017   ['Jessica Simpson', 'Luke Wilson', 'Rachael Le...
# 79509   ['Eric Roberts', 'Megan Gallagher', 'James Ear...
# 13370   ['Bob Balaban', 'Christopher Guest', 'John Mic...
# 480623  ['Bridget Regan', 'Travis Van Winkle', 'Raven ...
# 465109  ['Adam Sandler', 'Chris Rock', 'Steve Buscemi'...
#
# [9130 rows x 1 columns]

# %% [markdown]
# ### Sum of Vectors

# %%
def get_sum_of_vectors(df: pd.DataFrame, df_vectors: pd.DataFrame, unique_list: list)->pd.DataFrame:
    df_vectors_sum = pd.DataFrame(index=df.index, columns=u_genres)
    
    def get_sum(row):
        _id = row.name
        _ids = df_vectors.loc[df.loc[_id].to_list()[0][2:-2].split("', '")]
        
        return _ids.sum()

    df_vectors_sum = df.apply(get_sum, axis=1)
    
    return df_vectors_sum

# %%
keywords_sum_vectors = get_sum_of_vectors(keywords, keywords_vectors, u_keywords)
keywords_sum_vectors.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687     395        243        104     302    178            2    258
# 697843     266        188         69     168     75            1     85
# 603692     678        389        143     534    432            7    475
# 569094     863        574        337     367    165            9    144
# 502356     314        346        207     519     81            4    171
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687     184      123       17     225     14       73       88
# 697843     105       81        6     149      9       43       27
# 603692     209      197       27     216     37      156      178
# 569094     252      308        3     224     16       95       47
# 502356     262      180       20      88     38       44      102
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687              140        23       353   11       27
# 697843              118        16       194   16        2
# 603692              239        20       562   15        8
# 569094              522        41       279   10        8
# 502356              163         3       135   12       11

# %%
keywords_sum_vectors.to_csv('data/keywords_sum_vectors.csv')

# %%
crew_sum_vectors = get_sum_of_vectors(crew, crew_vectors, u_crew)
crew_sum_vectors.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687     234        116          2      81    123            1    115
# 697843     153         85          3      35     33            0     52
# 603692     178         80          5      81     89            1     83
# 569094     295        269        202     122     25            2     59
# 502356      15         71        104      97      4            0      3
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687      34       61       20      34      6       21       40
# 697843      16       33        3      14      0       11       14
# 603692       5       32       14      35      2       36       30
# 569094      94      102       10      25      7       16       16
# 502356      96       48        0       0      6        1        0
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687               61         0       165    9        1
# 697843               67         0        88    2        1
# 603692               59         0       163   14        2
# 569094              202         7        53    4        1
# 502356                5         1         0    0        0

# %%
crew_sum_vectors.to_csv('data/crew_sum_vectors.csv')

# %%
cast_sum_vectors = get_sum_of_vectors(cast, cast_vectors, u_cast)
cast_sum_vectors.head()
# Out:
#         Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  \
# id
# 385687     284        137         31     140    174            6    135
# 697843     119         57          4      33     27            1     34
# 603692     176         81         26      75     88            3    113
# 569094     369        435        406     402     77            6    243
# 502356     193        281        442     429     31            3     69
#
#         Family  Fantasy  History  Horror  Music  Mystery  Romance  \
# id
# 385687      52       54       13      21      5       24       42
# 697843       7       27        3       8      0        9        4
# 603692      29       45       12      28      5       25       23
# 569094     245      160       29      30     33       48       92
# 502356     372      175        9      31     29       45       34
#
#         Science Fiction  TV Movie  Thriller  War  Western
# id
# 385687               76         5       194   12        1
# 697843               30         1        72    3        1
# 603692               53         7       136    7        6
# 569094              257         9       116   12       14
# 502356              130        34        49    1        3

# %%
cast_sum_vectors.to_csv('data/cast_sum_vectors.csv')
